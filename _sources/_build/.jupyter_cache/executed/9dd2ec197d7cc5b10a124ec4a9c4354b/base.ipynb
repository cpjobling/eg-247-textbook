% %%
% Matlab setup
clear all
cd ../matlab 
pwd
format compact
% Out:
% ans =
%
%     '/Users/eechris/code/src/github.com/cpjobling/eg-247-textbook/transfer_functions/matlab'

% %%
syms s;

% %%
R1 = 200*10^3; 
R2 = 40*10^3;
R3 = 50*10^3;

C1 = 25*10^(-9);
C2 = 10*10^(-9);

% %%
den = R1*((1/R1+ 1/R2 + 1/R3 + s*C1)*(s*R3*C2) + 1/R2);
simplify(den)
% Out:
% ans =
% 100*s*((7555786372591433*s)/302231454903657293676544 + 1/20000) + 5

% %%
format long
denG = sym2poly(ans)
% Out:
% denG =
%    0.000002500000000   0.005000000000000   5.000000000000000

% %%
numG = -1;

% %%
a = denG(1);
b = denG(2);

% %%
w = 1:10:10000;
Gs = -1./(a*w.^2 - j.*b.*w + denG(3));

% %%
semilogx(w, abs(Gs))
xlabel('Radian frequency w (rad/s')
ylabel('|Vout/Vin|')
title('Magnitude Vout/Vin vs. Radian Frequency')
grid

% %%
G = tf([-1],[1 3 1])
% Out:
% G =
%        -1
%   -------------
%   s^2 + 3 s + 1
% Continuous-time transfer function.

% %%
step(G)

% %%
open example_8

% %%
bode(G), grid
